# %%
import numpy as np
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

def kmeans(X,K,max_iters=100):
    centroid = X[:K]
    for _ in range(max_iters):
        expanded_x = X[:,np.newaxis]
        eucledian = np.linalg.norm(expanded_x-centroid,axis=2)
        labels = np.argmin(eucledian,axis=1)
    
        new_centroids = [X[labels==k].mean(axis=0) for k in range(K)]
    
        if np.all(centroid == new_centroids):
            break
        centriod =new_centroids
    return labels,centroid

x = load_iris() .data
labels , centroid = kmeans(x,3)

plt.scatter(x[:,0],x[:,1],c=labels)
plt.scatter(centroid[:,0],centroid[:,1],marker='x',color='red')
plt.show()
