# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('../ToyotaCorolla.csv')
x = df['Doors']
y = df['KM']
z = df['Price']
ax = plt.axes(projection='3d')
ax.plot_trisurf(y,x,z,cmap='jet')
ax.set_title('#D')
plt.show()
